# %% [markdown]
# # Exploratory Analysis on NBA Shot Log Data

# %% [markdown]
# This notebook will do some exploratory analysis based on the 2014-2015 NBA Shot log data from Kaggle (credit to Dans Becker)

# %% [markdown]
# # Step 1: Loading the Data

# %%
import pandas as pd

# %%
nba_data = pd.read_csv('E:/Random_Projects/NBA-Stuff/data/shot_logs.csv')

# %% [markdown]
# # Step 2: Properties of the Data

# %% [markdown]
# Some questions to consider
# * What are the data types of each column (format, etc.)?
# * What attributes are missing, if any?
#
# Using the info method we can see that the the shot clock data, has missing values and tell which data is numeric vs non numeric

# %%
nba_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128069 entries, 0 to 128068
# Data columns (total 21 columns):
# GAME_ID                       128069 non-null int64
# MATCHUP                       128069 non-null object
# LOCATION                      128069 non-null object
# W                             128069 non-null object
# FINAL_MARGIN                  128069 non-null int64
# SHOT_NUMBER                   128069 non-null int64
# PERIOD                        128069 non-null int64
# GAME_CLOCK                    128069 non-null object
# SHOT_CLOCK                    122502 non-null float64
# DRIBBLES                      128069 non-null int64
# TOUCH_TIME                    128069 non-null float64
# SHOT_DIST                     128069 non-null float64
# PTS_TYPE                      128069 non-null int64
# SHOT_RESULT                   128069 non-null object
# CLOSEST_DEFENDER              128069 non-null object
# CLOSEST_DEFENDER_PLAYER_ID    128069 non-null int64
# CLOSE_DEF_DIST                128069 non-null float64
# FGM                           128069 non-null int64
# PTS                           128069 non-null int64
# player_name                   128069 non-null object
# player_id                     128069 non-null int64
# dtypes: float64(4), int64(10), object(7)
# memory usage: 20.5+ MB

# %%
nba_data.head(5)
# Out:
#     GAME_ID                   MATCHUP LOCATION  W  FINAL_MARGIN  SHOT_NUMBER  \
# 0  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            1
# 1  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            2
# 2  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            3
# 3  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            4
# 4  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            5
#
#    PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES    ...     SHOT_DIST  PTS_TYPE  \
# 0       1       1:09        10.8         2    ...           7.7         2
# 1       1       0:14         3.4         0    ...          28.2         3
# 2       1       0:00         NaN         3    ...          10.1         2
# 3       2      11:47        10.3         2    ...          17.2         2
# 4       2      10:34        10.9         2    ...           3.7         2
#
#    SHOT_RESULT   CLOSEST_DEFENDER CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  \
# 0         made     Anderson, Alan                     101187             1.3
# 1       missed  Bogdanovic, Bojan                     202711             6.1
# 2       missed  Bogdanovic, Bojan                     202711             0.9
# 3       missed      Brown, Markel                     203900             3.4
# 4       missed    Young, Thaddeus                     201152             1.1
#
#    FGM  PTS    player_name player_id
# 0    1    2  brian roberts    203148
# 1    0    0  brian roberts    203148
# 2    0    0  brian roberts    203148
# 3    0    0  brian roberts    203148
# 4    0    0  brian roberts    203148
#
# [5 rows x 21 columns]

# %%
nba_data.tail(10)
# Out:
#          GAME_ID                   MATCHUP LOCATION  W  FINAL_MARGIN  \
# 128059  21400033  NOV 01, 2014 - BKN @ DET        A  W            12
# 128060  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128061  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128062  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128063  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128064  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128065  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128066  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128067  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128068  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
#
#         SHOT_NUMBER  PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES    ...     \
# 128059            4       4       8:34        19.8         0    ...
# 128060            1       1       1:59        11.4        16    ...
# 128061            2       2      10:10        19.0         0    ...
# 128062            3       2       7:46         7.0         1    ...
# 128063            4       2       5:05        15.3         2    ...
# 128064            5       3       1:52        18.3         5    ...
# 128065            6       4      11:28        19.8         4    ...
# 128066            7       4      11:10        23.0         2    ...
# 128067            8       4       2:37         9.1         4    ...
# 128068            9       4       0:12         NaN         5    ...
#
#         SHOT_DIST  PTS_TYPE  SHOT_RESULT  CLOSEST_DEFENDER  \
# 128059       22.7         3       missed    Augustin, D.J.
# 128060       12.6         2       missed      Rondo, Rajon
# 128061        7.4         2       missed    Bradley, Avery
# 128062       14.5         2         made     Smart, Marcus
# 128063        8.9         2         made  Sullinger, Jared
# 128064        8.7         2       missed     Smart, Marcus
# 128065        0.6         2         made      Turner, Evan
# 128066       16.9         2         made  Thornton, Marcus
# 128067       18.3         2       missed    Bradley, Avery
# 128068        5.1         2         made    Bradley, Avery
#
#        CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  FGM  PTS   player_name  \
# 128059                     201571             4.0    0    0  jarrett jack
# 128060                     200765             4.8    0    0  jarrett jack
# 128061                     202340             2.7    0    0  jarrett jack
# 128062                     203935             3.1    1    2  jarrett jack
# 128063                     203096             5.7    1    2  jarrett jack
# 128064                     203935             0.8    0    0  jarrett jack
# 128065                     202323             0.6    1    2  jarrett jack
# 128066                     201977             4.2    1    2  jarrett jack
# 128067                     202340             3.0    0    0  jarrett jack
# 128068                     202340             2.3    1    2  jarrett jack
#
#        player_id
# 128059    101127
# 128060    101127
# 128061    101127
# 128062    101127
# 128063    101127
# 128064    101127
# 128065    101127
# 128066    101127
# 128067    101127
# 128068    101127
#
# [10 rows x 21 columns]

# %% [markdown]
# # Step 3: Data Cleaning
#
# Now we're going to make some some adjustments to make the data easier to read.

# %%
#fixing column names

column_list = list(nba_data.columns)

#remove underscore and lowercase data

proper_col = [(col.replace('_', ' ')).title() for col in column_list]

nba_data.columns = proper_col

# %% [markdown]
# Now the Matchup Column has a lot of information that can be split into separate columns. Right now it is not really clear which team is the home team or the away team. It is broken down the following way:
#
# * Date
#
# * Home Team
#
# * Away Team
#
# We'll create functions that we can use on the series to each part, but let's try with one example

# %%
matchup = nba_data['Matchup']

# %%
sample_date = matchup[0].split(' - ')[0]

print(sample_date)
# Out:
# MAR 04, 2015

# %% [markdown]
# Now we can use the datetime module to parse the date information

# %%
from datetime import datetime

parsed_date = (datetime.strptime(sample_date, '%b %d, %Y')).date()

print(parsed_date)
# Out:
# 2015-03-04

# %% [markdown]
# Now we have a way to create a function to return the parsed date information

# %%
def get_date(s):
    date = s.split(' - ')[0]
    parsed_date = (datetime.strptime(sample_date, '%b %d, %Y')).date()
    return parsed_date

# %%
game_date = nba_data['Matchup'].apply(get_date)

nba_data['Date'] = game_date

# %% [markdown]
# Repeat with the Home and Away Team Names. Since @ and vs. are both delimeter cases, we can use regex to split terms and create a function for each part. Below is a sample of what we'll do for the home team

# %%
import re

sample = nba_data['Matchup']

row_1 = sample[0].split(' - ')[1]

first_val = re.split('\s@\s|\svs\.\s' ,row_1)[1]

first_val
# Out:
# 4
# 'BKN'

# %%
def get_home_team(s):
    second_part = s.split(' - ')[1]
    if second_part.find('@') >= 1:
        return re.split('\s@\s|\svs\.\s' , second_part)[1]
    else:
        return re.split('\s@\s|\svs\.\s' , second_part)[0]

def get_away_team(s):
    second_part = s.split(' - ')[1]
    if second_part.find('@') >= 1:
        return re.split('\s@\s|\svs\.\s' , second_part)[0]
    else:
        return re.split('\s@\s|\svs\.\s' , second_part)[1]

# %%
home_team = nba_data['Matchup'].apply(get_home_team)

away_team = nba_data['Matchup'].apply(get_away_team)

nba_data['Home Team'] = home_team

nba_data['Away Team'] = away_team

nba_data[['Matchup', 'Home Team', 'Away Team']]
# Out:
#                            Matchup Home Team Away Team
# 0         MAR 04, 2015 - CHA @ BKN       BKN       CHA
# 1         MAR 04, 2015 - CHA @ BKN       BKN       CHA
# 2         MAR 04, 2015 - CHA @ BKN       BKN       CHA
# 3         MAR 04, 2015 - CHA @ BKN       BKN       CHA
# 4         MAR 04, 2015 - CHA @ BKN       BKN       CHA
# 5         MAR 04, 2015 - CHA @ BKN       BKN       CHA
# 6         MAR 04, 2015 - CHA @ BKN       BKN       CHA
# 7         MAR 04, 2015 - CHA @ BKN       BKN       CHA
# 8         MAR 04, 2015 - CHA @ BKN       BKN       CHA
# 9       MAR 03, 2015 - CHA vs. LAL       CHA       LAL
# 10      MAR 03, 2015 - CHA vs. LAL       CHA       LAL
# 11      MAR 03, 2015 - CHA vs. LAL       CHA       LAL
# 12      MAR 03, 2015 - CHA vs. LAL       CHA       LAL
# 13        MAR 01, 2015 - CHA @ ORL       ORL       CHA
# 14        FEB 27, 2015 - CHA @ BOS       BOS       CHA
# 15        FEB 27, 2015 - CHA @ BOS       BOS       CHA
# 16        FEB 27, 2015 - CHA @ BOS       BOS       CHA
# 17        FEB 27, 2015 - CHA @ BOS       BOS       CHA
# 18        FEB 27, 2015 - CHA @ BOS       BOS       CHA
# 19        FEB 25, 2015 - CHA @ CHI       CHI       CHA
# 20        FEB 25, 2015 - CHA @ CHI       CHI       CHA
# 21        FEB 25, 2015 - CHA @ CHI       CHI       CHA
# 22        FEB 25, 2015 - CHA @ CHI       CHI       CHA
# 23        FEB 25, 2015 - CHA @ CHI       CHI       CHA
# 24        FEB 25, 2015 - CHA @ CHI       CHI       CHA
# 25        FEB 25, 2015 - CHA @ CHI       CHI       CHA
# 26        FEB 25, 2015 - CHA @ CHI       CHI       CHA
# 27        FEB 22, 2015 - CHA @ DAL       DAL       CHA
# 28        FEB 22, 2015 - CHA @ DAL       DAL       CHA
# 29        FEB 22, 2015 - CHA @ DAL       DAL       CHA
# ...                            ...       ...       ...
# 128039  NOV 07, 2014 - BKN vs. NYK       BKN       NYK
# 128040  NOV 07, 2014 - BKN vs. NYK       BKN       NYK
# 128041  NOV 07, 2014 - BKN vs. NYK       BKN       NYK
# 128042  NOV 07, 2014 - BKN vs. NYK       BKN       NYK
# 128043  NOV 05, 2014 - BKN vs. MIN       BKN       MIN
# 128044  NOV 05, 2014 - BKN vs. MIN       BKN       MIN
# 128045  NOV 05, 2014 - BKN vs. MIN       BKN       MIN
# 128046  NOV 05, 2014 - BKN vs. MIN       BKN       MIN
# 128047  NOV 05, 2014 - BKN vs. MIN       BKN       MIN
# 128048  NOV 05, 2014 - BKN vs. MIN       BKN       MIN
# 128049  NOV 05, 2014 - BKN vs. MIN       BKN       MIN
# 128050  NOV 05, 2014 - BKN vs. MIN       BKN       MIN
# 128051  NOV 03, 2014 - BKN vs. OKC       BKN       OKC
# 128052  NOV 03, 2014 - BKN vs. OKC       BKN       OKC
# 128053  NOV 03, 2014 - BKN vs. OKC       BKN       OKC
# 128054  NOV 03, 2014 - BKN vs. OKC       BKN       OKC
# 128055  NOV 03, 2014 - BKN vs. OKC       BKN       OKC
# 128056    NOV 01, 2014 - BKN @ DET       DET       BKN
# 128057    NOV 01, 2014 - BKN @ DET       DET       BKN
# 128058    NOV 01, 2014 - BKN @ DET       DET       BKN
# 128059    NOV 01, 2014 - BKN @ DET       DET       BKN
# 128060    OCT 29, 2014 - BKN @ BOS       BOS       BKN
# 128061    OCT 29, 2014 - BKN @ BOS       BOS       BKN
# 128062    OCT 29, 2014 - BKN @ BOS       BOS       BKN
# 128063    OCT 29, 2014 - BKN @ BOS       BOS       BKN
# 128064    OCT 29, 2014 - BKN @ BOS       BOS       BKN
# 128065    OCT 29, 2014 - BKN @ BOS       BOS       BKN
# 128066    OCT 29, 2014 - BKN @ BOS       BOS       BKN
# 128067    OCT 29, 2014 - BKN @ BOS       BOS       BKN
# 128068    OCT 29, 2014 - BKN @ BOS       BOS       BKN
#
# [128069 rows x 3 columns]

# %% [markdown]
# Now that we've parsed all the information in the cluttered Matchup column, we don't really need it anymore. We can now remove that column from the data

# %%
nba_clean_1 = nba_data.drop('Matchup', axis =1)

# %%
nba_clean_1
# Out:
#          Game Id Location  W  Final Margin  Shot Number  Period Game Clock  \
# 0       21400899        A  W            24            1       1       1:09
# 1       21400899        A  W            24            2       1       0:14
# 2       21400899        A  W            24            3       1       0:00
# 3       21400899        A  W            24            4       2      11:47
# 4       21400899        A  W            24            5       2      10:34
# 5       21400899        A  W            24            6       2       8:15
# 6       21400899        A  W            24            7       4      10:15
# 7       21400899        A  W            24            8       4       8:00
# 8       21400899        A  W            24            9       4       5:14
# 9       21400890        H  W             1            1       2      11:32
# 10      21400890        H  W             1            2       2       6:30
# 11      21400890        H  W             1            3       4      11:32
# 12      21400890        H  W             1            4       4       8:55
# 13      21400882        A  W            15            1       4       9:10
# 14      21400859        A  L            -8            1       1       0:48
# 15      21400859        A  L            -8            2       2      10:38
# 16      21400859        A  L            -8            3       2       8:27
# 17      21400859        A  L            -8            4       4      10:55
# 18      21400859        A  L            -8            5       4      10:29
# 19      21400845        A  W            12            1       1       3:35
# 20      21400845        A  W            12            2       1       0:33
# 21      21400845        A  W            12            3       2       8:50
# 22      21400845        A  W            12            4       2       8:24
# 23      21400845        A  W            12            5       2       5:32
# 24      21400845        A  W            12            6       2       0:04
# 25      21400845        A  W            12            7       4      10:13
# 26      21400845        A  W            12            8       4       5:34
# 27      21400827        A  L           -11            1       1       2:25
# 28      21400827        A  L           -11            2       2       9:08
# 29      21400827        A  L           -11            3       2       8:53
# ...          ...      ... ..           ...          ...     ...        ...
# 128039  21400075        H  W            11            2       2       9:05
# 128040  21400075        H  W            11            3       4      11:13
# 128041  21400075        H  W            11            4       4       4:23
# 128042  21400075        H  W            11            5       4       0:06
# 128043  21400060        H  L            -7            1       2      11:48
# 128044  21400060        H  L            -7            2       2      10:05
# 128045  21400060        H  L            -7            3       2       9:34
# 128046  21400060        H  L            -7            4       3       4:01
# 128047  21400060        H  L            -7            5       3       3:05
# 128048  21400060        H  L            -7            6       4      11:01
# 128049  21400060        H  L            -7            7       4       7:27
# 128050  21400060        H  L            -7            8       4       6:41
# 128051  21400044        H  W            31            2       1       0:16
# 128052  21400044        H  W            31            3       2      10:29
# 128053  21400044        H  W            31            4       3       6:15
# 128054  21400044        H  W            31            5       3       3:17
# 128055  21400044        H  W            31            6       4      11:22
# 128056  21400033        A  W            12            1       1       1:50
# 128057  21400033        A  W            12            2       2      10:02
# 128058  21400033        A  W            12            3       4      10:57
# 128059  21400033        A  W            12            4       4       8:34
# 128060  21400006        A  L           -16            1       1       1:59
# 128061  21400006        A  L           -16            2       2      10:10
# 128062  21400006        A  L           -16            3       2       7:46
# 128063  21400006        A  L           -16            4       2       5:05
# 128064  21400006        A  L           -16            5       3       1:52
# 128065  21400006        A  L           -16            6       4      11:28
# 128066  21400006        A  L           -16            7       4      11:10
# 128067  21400006        A  L           -16            8       4       2:37
# 128068  21400006        A  L           -16            9       4       0:12
#
#         Shot Clock  Dribbles  Touch Time    ...        Closest Defender  \
# 0             10.8         2         1.9    ...          Anderson, Alan
# 1              3.4         0         0.8    ...       Bogdanovic, Bojan
# 2              NaN         3         2.7    ...       Bogdanovic, Bojan
# 3             10.3         2         1.9    ...           Brown, Markel
# 4             10.9         2         2.7    ...         Young, Thaddeus
# 5              9.1         2         4.4    ...         Williams, Deron
# 6             14.5        11         9.0    ...           Jack, Jarrett
# 7              3.4         3         2.5    ...          Plumlee, Mason
# 8             12.4         0         0.8    ...          Morris, Darius
# 9             17.4         0         1.1    ...        Ellington, Wayne
# 10            16.0         8         7.5    ...             Lin, Jeremy
# 11            12.1        14        11.9    ...             Lin, Jeremy
# 12             4.3         2         2.9    ...            Hill, Jordan
# 13             4.4         0         0.8    ...           Green, Willie
# 14             6.8         0         0.5    ...           Smart, Marcus
# 15             6.4         3         2.7    ...            Young, James
# 16            17.6         6         5.1    ...          Jerebko, Jonas
# 17             8.7         1         0.9    ...            Crowder, Jae
# 18            20.8         0         1.2    ...          Thomas, Isaiah
# 19            17.5         2         2.2    ...           Brooks, Aaron
# 20            19.5         5         4.4    ...           Hinrich, Kirk
# 21             6.0         6         7.4    ...             Gibson, Taj
# 22            15.7         0         0.7    ...           Hinrich, Kirk
# 23            11.2        16        13.4    ...             Gibson, Taj
# 24             NaN         0         0.7    ...           Butler, Jimmy
# 25            17.1         7         7.2    ...            Noah, Joakim
# 26            15.4         1         1.6    ...           Brooks, Aaron
# 27            12.3         0         0.8    ...           Harris, Devin
# 28            18.2         7         5.2    ...        Barea, Jose Juan
# 29            11.9         1         2.1    ...        Barea, Jose Juan
# ...            ...       ...         ...    ...                     ...
# 128039         7.9         6         6.3    ...           Larkin, Shane
# 128040         8.8         0         0.5    ...            Smith, Jason
# 128041        10.3         3         2.1    ...           Larkin, Shane
# 128042         4.0        20        20.4    ...            Wear, Travis
# 128043        12.1        16        12.0    ...            Williams, Mo
# 128044         8.4         3         3.2    ...            Williams, Mo
# 128045         9.0         0         0.0    ...           Dieng, Gorgui
# 128046        19.3         2         1.9    ...           Martin, Kevin
# 128047         7.3         6         6.9    ...            Williams, Mo
# 128048         9.0         0         1.0    ...           Brewer, Corey
# 128049        11.0         2         2.2    ...         Pekovic, Nikola
# 128050        22.7         1         2.0    ...            Williams, Mo
# 128051         NaN         3         3.7    ...      Telfair, Sebastian
# 128052        19.3         2         3.2    ...      Telfair, Sebastian
# 128053         3.2         5         5.1    ...           Adams, Steven
# 128054         4.1         2         2.1    ...      Telfair, Sebastian
# 128055        13.8         0         0.6    ...         Jackson, Reggie
# 128056         7.1         2         2.3    ...       Jennings, Brandon
# 128057         7.3         0         1.0    ...          Augustin, D.J.
# 128058        14.3         2         2.0    ...          Augustin, D.J.
# 128059        19.8         0         0.8    ...          Augustin, D.J.
# 128060        11.4        16        12.4    ...            Rondo, Rajon
# 128061        19.0         0        -0.2    ...          Bradley, Avery
# 128062         7.0         1         1.7    ...           Smart, Marcus
# 128063        15.3         2         1.6    ...        Sullinger, Jared
# 128064        18.3         5         6.2    ...           Smart, Marcus
# 128065        19.8         4         5.2    ...            Turner, Evan
# 128066        23.0         2         4.2    ...        Thornton, Marcus
# 128067         9.1         4         4.5    ...          Bradley, Avery
# 128068         NaN         5         4.7    ...          Bradley, Avery
#
#         Closest Defender Player Id Close Def Dist Fgm  Pts    Player Name  \
# 0                           101187            1.3   1    2  brian roberts
# 1                           202711            6.1   0    0  brian roberts
# 2                           202711            0.9   0    0  brian roberts
# 3                           203900            3.4   0    0  brian roberts
# 4                           201152            1.1   0    0  brian roberts
# 5                           101114            2.6   0    0  brian roberts
# 6                           101127            6.1   0    0  brian roberts
# 7                           203486            2.1   1    2  brian roberts
# 8                           202721            7.3   0    0  brian roberts
# 9                           201961           19.8   0    0  brian roberts
# 10                          202391            4.7   0    0  brian roberts
# 11                          202391            1.8   1    2  brian roberts
# 12                          201941            5.4   1    2  brian roberts
# 13                            2584            4.4   0    0  brian roberts
# 14                          203935            5.3   0    0  brian roberts
# 15                          203923            5.6   1    3  brian roberts
# 16                          201973            5.4   0    0  brian roberts
# 17                          203109            5.1   0    0  brian roberts
# 18                          202738           11.1   1    3  brian roberts
# 19                          201166            3.5   0    0  brian roberts
# 20                            2550            4.0   1    2  brian roberts
# 21                          201959            5.4   1    2  brian roberts
# 22                            2550            3.7   0    0  brian roberts
# 23                          201959            5.1   1    3  brian roberts
# 24                          202710            3.6   0    0  brian roberts
# 25                          201149            6.0   1    3  brian roberts
# 26                          201166            0.7   1    2  brian roberts
# 27                            2734            3.5   0    0  brian roberts
# 28                          200826            4.5   0    0  brian roberts
# 29                          200826            3.5   0    0  brian roberts
# ...                            ...            ...  ..  ...            ...
# 128039                      203499            1.2   0    0   jarrett jack
# 128040                      201160            5.1   0    0   jarrett jack
# 128041                      203499            0.9   1    2   jarrett jack
# 128042                      204037            0.9   1    2   jarrett jack
# 128043                        2590            2.5   1    2   jarrett jack
# 128044                        2590            1.8   0    0   jarrett jack
# 128045                      203476            1.5   0    0   jarrett jack
# 128046                        2755            3.6   0    0   jarrett jack
# 128047                        2590            2.4   1    2   jarrett jack
# 128048                      201147           11.1   1    2   jarrett jack
# 128049                      201593            6.0   1    2   jarrett jack
# 128050                        2590            7.7   1    2   jarrett jack
# 128051                        2742            5.4   1    2   jarrett jack
# 128052                        2742            3.8   0    0   jarrett jack
# 128053                      203500            2.8   0    0   jarrett jack
# 128054                        2742            4.2   0    0   jarrett jack
# 128055                      202704            2.1   0    0   jarrett jack
# 128056                      201943            3.1   0    0   jarrett jack
# 128057                      201571            2.9   0    0   jarrett jack
# 128058                      201571            1.1   1    2   jarrett jack
# 128059                      201571            4.0   0    0   jarrett jack
# 128060                      200765            4.8   0    0   jarrett jack
# 128061                      202340            2.7   0    0   jarrett jack
# 128062                      203935            3.1   1    2   jarrett jack
# 128063                      203096            5.7   1    2   jarrett jack
# 128064                      203935            0.8   0    0   jarrett jack
# 128065                      202323            0.6   1    2   jarrett jack
# 128066                      201977            4.2   1    2   jarrett jack
# 128067                      202340            3.0   0    0   jarrett jack
# 128068                      202340            2.3   1    2   jarrett jack
#
#         Player Id        Date Home Team  Away Team
# 0          203148  2015-03-04       BKN        CHA
# 1          203148  2015-03-04       BKN        CHA
# 2          203148  2015-03-04       BKN        CHA
# 3          203148  2015-03-04       BKN        CHA
# 4          203148  2015-03-04       BKN        CHA
# 5          203148  2015-03-04       BKN        CHA
# 6          203148  2015-03-04       BKN        CHA
# 7          203148  2015-03-04       BKN        CHA
# 8          203148  2015-03-04       BKN        CHA
# 9          203148  2015-03-04       CHA        LAL
# 10         203148  2015-03-04       CHA        LAL
# 11         203148  2015-03-04       CHA        LAL
# 12         203148  2015-03-04       CHA        LAL
# 13         203148  2015-03-04       ORL        CHA
# 14         203148  2015-03-04       BOS        CHA
# 15         203148  2015-03-04       BOS        CHA
# 16         203148  2015-03-04       BOS        CHA
# 17         203148  2015-03-04       BOS        CHA
# 18         203148  2015-03-04       BOS        CHA
# 19         203148  2015-03-04       CHI        CHA
# 20         203148  2015-03-04       CHI        CHA
# 21         203148  2015-03-04       CHI        CHA
# 22         203148  2015-03-04       CHI        CHA
# 23         203148  2015-03-04       CHI        CHA
# 24         203148  2015-03-04       CHI        CHA
# 25         203148  2015-03-04       CHI        CHA
# 26         203148  2015-03-04       CHI        CHA
# 27         203148  2015-03-04       DAL        CHA
# 28         203148  2015-03-04       DAL        CHA
# 29         203148  2015-03-04       DAL        CHA
# ...           ...         ...       ...        ...
# 128039     101127  2015-03-04       BKN        NYK
# 128040     101127  2015-03-04       BKN        NYK
# 128041     101127  2015-03-04       BKN        NYK
# 128042     101127  2015-03-04       BKN        NYK
# 128043     101127  2015-03-04       BKN        MIN
# 128044     101127  2015-03-04       BKN        MIN
# 128045     101127  2015-03-04       BKN        MIN
# 128046     101127  2015-03-04       BKN        MIN
# 128047     101127  2015-03-04       BKN        MIN
# 128048     101127  2015-03-04       BKN        MIN
# 128049     101127  2015-03-04       BKN        MIN
# 128050     101127  2015-03-04       BKN        MIN
# 128051     101127  2015-03-04       BKN        OKC
# 128052     101127  2015-03-04       BKN        OKC
# 128053     101127  2015-03-04       BKN        OKC
# 128054     101127  2015-03-04       BKN        OKC
# 128055     101127  2015-03-04       BKN        OKC
# 128056     101127  2015-03-04       DET        BKN
# 128057     101127  2015-03-04       DET        BKN
# 128058     101127  2015-03-04       DET        BKN
# 128059     101127  2015-03-04       DET        BKN
# 128060     101127  2015-03-04       BOS        BKN
# 128061     101127  2015-03-04       BOS        BKN
# 128062     101127  2015-03-04       BOS        BKN
# 128063     101127  2015-03-04       BOS        BKN
# 128064     101127  2015-03-04       BOS        BKN
# 128065     101127  2015-03-04       BOS        BKN
# 128066     101127  2015-03-04       BOS        BKN
# 128067     101127  2015-03-04       BOS        BKN
# 128068     101127  2015-03-04       BOS        BKN
#
# [128069 rows x 23 columns]

# %%
nba_clean_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128069 entries, 0 to 128068
# Data columns (total 23 columns):
# Game Id                       128069 non-null int64
# Location                      128069 non-null object
# W                             128069 non-null object
# Final Margin                  128069 non-null int64
# Shot Number                   128069 non-null int64
# Period                        128069 non-null int64
# Game Clock                    128069 non-null object
# Shot Clock                    122502 non-null float64
# Dribbles                      128069 non-null int64
# Touch Time                    128069 non-null float64
# Shot Dist                     128069 non-null float64
# Pts Type                      128069 non-null int64
# Shot Result                   128069 non-null object
# Closest Defender              128069 non-null object
# Closest Defender Player Id    128069 non-null int64
# Close Def Dist                128069 non-null float64
# Fgm                           128069 non-null int64
# Pts                           128069 non-null int64
# Player Name                   128069 non-null object
# Player Id                     128069 non-null int64
# Date                          128069 non-null object
# Home Team                     128069 non-null object
# Away Team                     128069 non-null object
# dtypes: float64(4), int64(10), object(9)
# memory usage: 22.5+ MB

# %% [markdown]
# Part 2 will further clean the data columns to make it easier for analysis
